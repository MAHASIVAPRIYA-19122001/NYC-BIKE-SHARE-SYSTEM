# %%
import pandas as pd

# %%
df=pd.read_csv("merged-tripdata.csv",error_bad_lines=False,engine="python")

# %%
df.head()
# Out:
#    tripduration         starttime          stoptime  start station id  \
# 0           634  01-07-2013 00:00  01-07-2013 00:10               164
# 1          1547  01-07-2013 00:00  01-07-2013 00:25               388
# 2           178  01-07-2013 00:01  01-07-2013 00:04               293
# 3          1580  01-07-2013 00:01  01-07-2013 00:27               531
# 4           757  01-07-2013 00:01  01-07-2013 00:13               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# 0             504          1 Ave & E 15 St             40.732219
# 1             459         W 20 St & 11 Ave             40.746745
# 2             237          E 11 St & 2 Ave             40.730473
# 3             499       Broadway & W 60 St             40.769155
# 4             410  Suffolk St & Stanton St             40.720664
#
#    end station longitude   bikeid    usertype birthyear  gender
# 0             -73.981656  16950.0    Customer        \N     0.0
# 1             -74.007756  19816.0    Customer        \N     0.0
# 2             -73.986724  14548.0  Subscriber      1980     2.0
# 3             -73.981918  16063.0    Customer        \N     0.0
# 4             -73.985180  19213.0  Subscriber      1986     1.0

# %%
df2=pd.DataFrame()
df2['available']=df['gender']

# %%
df2.head()
# Out:
#    available
# 0        0.0
# 1        0.0
# 2        2.0
# 3        0.0
# 4        1.0

# %%
df3=pd.DataFrame()
df3['start_time']=pd.to_datetime(df['starttime'],errors='coerce',format='%Y-%m-%d %H:%M:%S')

# %%
df3['stop_time']=pd.to_datetime(df['stoptime'],errors='coerce',format='%Y-%m-%d %H:%M:%S')

# %%
df['startdate'] = pd.to_datetime(df3['start_time'])

# %%
df['stopdate'] = pd.to_datetime(df3['stop_time'])

# %%
df.head()
# Out:
#    tripduration         starttime          stoptime  start station id  \
# 0           634  01-07-2013 00:00  01-07-2013 00:10               164
# 1          1547  01-07-2013 00:00  01-07-2013 00:25               388
# 2           178  01-07-2013 00:01  01-07-2013 00:04               293
# 3          1580  01-07-2013 00:01  01-07-2013 00:27               531
# 4           757  01-07-2013 00:01  01-07-2013 00:13               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# 0             504          1 Ave & E 15 St             40.732219
# 1             459         W 20 St & 11 Ave             40.746745
# 2             237          E 11 St & 2 Ave             40.730473
# 3             499       Broadway & W 60 St             40.769155
# 4             410  Suffolk St & Stanton St             40.720664
#
#    end station longitude   bikeid    usertype birthyear  gender startdate  \
# 0             -73.981656  16950.0    Customer        \N     0.0       NaT
# 1             -74.007756  19816.0    Customer        \N     0.0       NaT
# 2             -73.986724  14548.0  Subscriber      1980     2.0       NaT
# 3             -73.981918  16063.0    Customer        \N     0.0       NaT
# 4             -73.985180  19213.0  Subscriber      1986     1.0       NaT
#
#   stopdate
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT

# %%
df['startmonth'] = df['startdate'].dt.month
df['startday'] = df['startdate'].dt.day
df['startminute'] = df['startdate'].dt.minute
df['startweek'] = df['startdate'].dt.minute
df['startweekday'] = df['startdate'].dt.minute
df['startweek'] = df['startdate'].dt.week
df['startweekofyear'] = df['startdate'].dt.weekofyear
df['startweekday'] = df['startdate'].dt.weekday
df['startdayofyear'] = df['startdate'].dt.dayofyear

df['startquarter'] = df['startdate'].dt.quarter
df['stopmonth'] = df['stopdate'].dt.month
df['stopday'] = df['startdate'].dt.day
df['stopminute'] = df['stopdate'].dt.minute
df['stopweek'] = df['stopdate'].dt.minute
df['stopweekday'] = df['stopdate'].dt.minute
df['stopdayofyear'] = df['stopdate'].dt.dayofyear
df['stopquarter'] = df['stopdate'].dt.quarter
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   import sys
#    tripduration         starttime          stoptime  start station id  \
# 0           634  01-07-2013 00:00  01-07-2013 00:10               164
# 1          1547  01-07-2013 00:00  01-07-2013 00:25               388
# 2           178  01-07-2013 00:01  01-07-2013 00:04               293
# 3          1580  01-07-2013 00:01  01-07-2013 00:27               531
# 4           757  01-07-2013 00:01  01-07-2013 00:13               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  ...  \
# 0             504          1 Ave & E 15 St             40.732219  ...
# 1             459         W 20 St & 11 Ave             40.746745  ...
# 2             237          E 11 St & 2 Ave             40.730473  ...
# 3             499       Broadway & W 60 St             40.769155  ...
# 4             410  Suffolk St & Stanton St             40.720664  ...
#
#    startweekofyear  startdayofyear startquarter stopmonth  stopday stopminute  \
# 0              NaN             NaN          NaN       NaN      NaN        NaN
# 1              NaN             NaN          NaN       NaN      NaN        NaN
# 2              NaN             NaN          NaN       NaN      NaN        NaN
# 3              NaN             NaN          NaN       NaN      NaN        NaN
# 4              NaN             NaN          NaN       NaN      NaN        NaN
#
#   stopweek  stopweekday  stopdayofyear  stopquarter
# 0      NaN          NaN            NaN          NaN
# 1      NaN          NaN            NaN          NaN
# 2      NaN          NaN            NaN          NaN
# 3      NaN          NaN            NaN          NaN
# 4      NaN          NaN            NaN          NaN
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#         tripduration         starttime          stoptime  start station id  \
# 796714           481  30-07-2013 18:50  30-07-2013 18:58               473
# 796715           873  30-07-2013 18:50  30-07-2013 19:04               329
# 796716           181  30-07-2013 18:50  30-07-2013 18:53               379
# 796717           453  30-07-2013 18:50  30-07-2013 18:57               323
# 796718           477  30-07-2013 18:50  30-07-2013 18:58               498
#
#                  start station name  start station latitude  \
# 796714   Rivington St & Chrystie St               40.721101
# 796715    Greenwich St & N Moore St               40.720434
# 796716              W 31 St & 7 Ave               40.749156
# 796717  Lawrence St & Willoughby St               40.692362
# 796718           Broadway & W 32 St               40.748549
#
#         start station longitude  end station id        end station name  \
# 796714               -73.991925             463         9 Ave & W 16 St
# 796715               -74.010206             453         W 22 St & 8 Ave
# 796716               -73.991600             512         W 29 St & 9 Ave
# 796717               -73.986317             271  Ashland Pl & Hanson Pl
# 796718               -73.988084             465               Broadway
#
#         end station latitude  ...  startweekofyear  startdayofyear  \
# 796714             40.742065  ...              NaN             NaN
# 796715             40.744751  ...              NaN             NaN
# 796716             40.750073  ...              NaN             NaN
# 796717             40.685282  ...              NaN             NaN
# 796718                   NaN  ...              NaN             NaN
#
#        startquarter stopmonth  stopday stopminute stopweek  stopweekday  \
# 796714          NaN       NaN      NaN        NaN      NaN          NaN
# 796715          NaN       NaN      NaN        NaN      NaN          NaN
# 796716          NaN       NaN      NaN        NaN      NaN          NaN
# 796717          NaN       NaN      NaN        NaN      NaN          NaN
# 796718          NaN       NaN      NaN        NaN      NaN          NaN
#
#         stopdayofyear  stopquarter
# 796714            NaN          NaN
# 796715            NaN          NaN
# 796716            NaN          NaN
# 796717            NaN          NaN
# 796718            NaN          NaN
#
# [5 rows x 32 columns]

# %%
df['stopweek'] = df['stopdate'].dt.isocalendar().week

# %%
df['stopweekofyear'] = df['stopdate'].dt.weekofyear
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
data=df.dropna()

# %%
data.isna().sum()
# Out:
# tripduration               0.0
# starttime                  0.0
# stoptime                   0.0
# start station id           0.0
# start station name         0.0
# start station latitude     0.0
# start station longitude    0.0
# end station id             0.0
# end station name           0.0
# end station latitude       0.0
# end station longitude      0.0
# bikeid                     0.0
# usertype                   0.0
# birthyear                  0.0
# gender                     0.0
# startdate                  0.0
# stopdate                   0.0
# startmonth                 0.0
# startday                   0.0
# startminute                0.0
# startweek                  0.0
# startweekday               0.0
# startweekofyear            0.0
# startdayofyear             0.0
# startquarter               0.0
# stopmonth                  0.0
# stopday                    0.0
# stopminute                 0.0
# stopweek                   0.0
# stopweekday                0.0
# stopdayofyear              0.0
# stopquarter                0.0
# stopweekofyear             0.0
# dtype: float64

# %%
data1=data.drop(['start station name'],axis=1)
data1.head()
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birthyear, gender, startdate, stopdate, startmonth, startday, startminute, startweek, startweekday, startweekofyear, startdayofyear, startquarter, stopmonth, stopday, stopminute, stopweek, stopweekday, stopdayofyear, stopquarter, stopweekofyear]
# Index: []
#
# [0 rows x 32 columns]

# %%
data1=data1.drop(['end station name'],axis=1)

# %%
data1.head()
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station latitude, start station longitude, end station id, end station latitude, end station longitude, bikeid, usertype, birthyear, gender, startdate, stopdate, startmonth, startday, startminute, startweek, startweekday, startweekofyear, startdayofyear, startquarter, stopmonth, stopday, stopminute, stopweek, stopweekday, stopdayofyear, stopquarter, stopweekofyear]
# Index: []
#
# [0 rows x 31 columns]

# %%
data1=data1.drop(['starttime'],axis=1)

# %%
data1=data1.drop(['stoptime'],axis=1)

# %%
data1['startmonth'] = data1['startmonth'].astype(int)

# %%
data1['startday'] = data1['startday'].astype(int)
data1['startminute'] = data1['startminute'].astype(int)
data1['startweek'] = data1['startweek'].astype(int)
data1['startweekday'] = data1['startweekday'].astype(int)
data1['startweekofyear'] = data1['startweekofyear'].astype(int)
data1['startdayofyear'] = data1['startdayofyear'].astype(int)

# %%
data1['startquarter'] = data1['startquarter'].astype(int)
data1['stopmonth'] = data1['stopmonth'].astype(int)
data1['stopday'] = data1['stopday'].astype(int)
data1['stopminute'] = data1['stopminute'].astype(int)
data1['stopweek'] = data1['stopweek'].astype(int)
data1['stopweekday'] = data1['stopweekday'].astype(int)
data1['stopweekofyear'] = data1['stopweekofyear'].astype(int)
data1['stopdayofyear'] = data1['stopdayofyear'].astype(int)
data1['stopquarter'] = data1['stopquarter'].astype(int)

# %%
display(data1.dtypes)
# Out:
# tripduration                        int64
# start station id                    int64
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station latitude              float64
# end station longitude             float64
# bikeid                            float64
# usertype                           object
# birthyear                          object
# gender                            float64
# startdate                  datetime64[ns]
# stopdate                   datetime64[ns]
# startmonth                          int64
# startday                            int64
# startminute                         int64
# startweek                           int64
# startweekday                        int64
# startweekofyear                     int64
# startdayofyear                      int64
# startquarter                        int64
# stopmonth                           int64
# stopday                             int64
# stopminute                          int64
# stopweek                            int64
# stopweekday                         int64
# stopdayofyear                       int64
# stopquarter                         int64
# stopweekofyear                      int64
# dtype: object

# %%
display(data1.dtypes)
# Out:
# tripduration                        int64
# start station id                    int64
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station latitude              float64
# end station longitude             float64
# bikeid                            float64
# usertype                           object
# birthyear                          object
# gender                            float64
# startdate                  datetime64[ns]
# stopdate                   datetime64[ns]
# startmonth                          int64
# startday                            int64
# startminute                         int64
# startweek                           int64
# startweekday                        int64
# startweekofyear                     int64
# startdayofyear                      int64
# startquarter                        int64
# stopmonth                           int64
# stopday                             int64
# stopminute                          int64
# stopweek                            int64
# stopweekday                         int64
# stopdayofyear                       int64
# stopquarter                         int64
# stopweekofyear                      int64
# dtype: object

# %%
df['startdate'] = df['startdate'].astype(str)

# %%
data1=data1.drop(['startdate'],axis=1)
data1=data1.drop(['stopdate'],axis=1)

# %%
data1.dtypes
# Out:
# tripduration                 int64
# start station id             int64
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station latitude       float64
# end station longitude      float64
# bikeid                     float64
# usertype                    object
# birthyear                   object
# gender                     float64
# startmonth                   int64
# startday                     int64
# startminute                  int64
# startweek                    int64
# startweekday                 int64
# startweekofyear              int64
# startdayofyear               int64
# startquarter                 int64
# stopmonth                    int64
# stopday                      int64
# stopminute                   int64
# stopweek                     int64
# stopweekday                  int64
# stopdayofyear                int64
# stopquarter                  int64
# stopweekofyear               int64
# dtype: object

# %%
df2.replace(2,1)
# Out:
#         available
# 0             0.0
# 1             0.0
# 2             1.0
# 3             0.0
# 4             1.0
# ...           ...
# 796714        1.0
# 796715        1.0
# 796716        1.0
# 796717        1.0
# 796718        NaN
#
# [796719 rows x 1 columns]

# %%
data2=df2.replace(2,1)

# %%
data2.head()
# Out:
#    available
# 0        0.0
# 1        0.0
# 2        1.0
# 3        0.0
# 4        1.0

# %%
data2['available']=data2['available'].dropna()

# %%
data2['available'] = data2['available'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-43-512abf64b83c> in <module>
# ----> 1 data2['available'] = data2['available'].astype(int)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1212     if not np.isfinite(values).all():
#    1213         raise IntCastingNaNError(
# -> 1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#    1216     return values.astype(dtype, copy=copy)
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data1, data2, test_size=0.20)

# %%
X_train.dtypes

# %%
y_train.dtypes

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test, y_pred)*100
print("The accuracy for the available of bikes is ",accuracy,"%")
